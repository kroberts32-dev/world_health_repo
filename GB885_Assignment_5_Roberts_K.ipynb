# %% [markdown]
# <a href="https://colab.research.google.com/github/kroberts32-dev/world_health_repo/blob/main/GB885_Assignment_5_Roberts_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #World Health Data
#
# Kasandra Roberts

# %%
#import necessary libraries
import pandas as pd
import numpy as np

# %%
#read a csv file from a url to a pandas dataframe

url = 'https://raw.githubusercontent.com/katiegaertner/ML-Fundamentals/main/world-health-data-numbers.csv'
world_health_data = pd.read_csv(url)

#check  work
world_health_data.head()
# Out:
#                 Country  Pop_Density Abbreviation  Land_Area  Birth_Rate  \
# 0               Andorra        164.0           AD      468.0        7.20
# 1  United Arab Emirates        118.0           AE    83600.0       10.33
# 2           Afghanistan         60.0           AF   652230.0       32.49
# 3   Antigua and Barbuda        223.0           AG      443.0       15.33
# 4               Albania        105.0           AL    28748.0       11.78
#
#    CO2_Emissions     CPI  Fertility_Rate           GDP  \
# 0          469.0     NaN            1.27  3.154058e+09
# 1       206324.0  114.52            1.41  4.211420e+11
# 2         8672.0  149.90            4.47  1.910135e+10
# 3          557.0  113.81            1.99  1.727759e+09
# 4         4536.0  119.05            1.62  1.527808e+10
#
#    Infant mortality_per_1k  Life_Expectancy  Maternal_Mortality_per_100k  \
# 0                      2.7              NaN                          NaN
# 1                      6.5             77.8                          3.0
# 2                     47.9             64.5                        638.0
# 3                      5.0             76.9                         42.0
# 4                      7.8             78.5                         15.0
#
#    Minimum_Wage Official Language  oop_health_exp  Physicians_per_1k  \
# 0          6.63           Catalan            0.36               3.33
# 1           NaN            Arabic            0.18               2.53
# 2          0.43            Pashto            0.78               0.28
# 3          3.04           English            0.24               2.76
# 4          1.12          Albanian            0.57               1.20
#
#    Population  Unemployment_Rate
# 0     77142.0                NaN
# 1   9770529.0               0.02
# 2  38041754.0               0.11
# 3     97118.0                NaN
# 4   2854191.0               0.12

# %%
# create dataframe
world_health_df = pd.DataFrame(world_health_data)

world_health_df.head()
# Out:
#                 Country  Pop_Density Abbreviation  Land_Area  Birth_Rate  \
# 0               Andorra        164.0           AD      468.0        7.20
# 1  United Arab Emirates        118.0           AE    83600.0       10.33
# 2           Afghanistan         60.0           AF   652230.0       32.49
# 3   Antigua and Barbuda        223.0           AG      443.0       15.33
# 4               Albania        105.0           AL    28748.0       11.78
#
#    CO2_Emissions     CPI  Fertility_Rate           GDP  \
# 0          469.0     NaN            1.27  3.154058e+09
# 1       206324.0  114.52            1.41  4.211420e+11
# 2         8672.0  149.90            4.47  1.910135e+10
# 3          557.0  113.81            1.99  1.727759e+09
# 4         4536.0  119.05            1.62  1.527808e+10
#
#    Infant mortality_per_1k  Life_Expectancy  Maternal_Mortality_per_100k  \
# 0                      2.7              NaN                          NaN
# 1                      6.5             77.8                          3.0
# 2                     47.9             64.5                        638.0
# 3                      5.0             76.9                         42.0
# 4                      7.8             78.5                         15.0
#
#    Minimum_Wage Official Language  oop_health_exp  Physicians_per_1k  \
# 0          6.63           Catalan            0.36               3.33
# 1           NaN            Arabic            0.18               2.53
# 2          0.43            Pashto            0.78               0.28
# 3          3.04           English            0.24               2.76
# 4          1.12          Albanian            0.57               1.20
#
#    Population  Unemployment_Rate
# 0     77142.0                NaN
# 1   9770529.0               0.02
# 2  38041754.0               0.11
# 3     97118.0                NaN
# 4   2854191.0               0.12

# %% [markdown]
# ### Question 1: How man rows are in the DataFrame?
#
# ### Question 2: How many columns are in the DataFrame?

# %%
# use shape to find row count
world_health_data.shape
# Out:
# (194, 18)

# %% [markdown]
# ## Update Notebook
#
# View the first 5 rows of the DataFrame
#
# Update the Abbreviations column to be the index

# %%
# Set abbreviations column as index

world_health_df = world_health_df.set_index('Abbreviation')

# %%
#Check work
world_health_df
# Out:
#                            Country  Pop_Density  Land_Area  Birth_Rate  \
# Abbreviation
# AD                         Andorra        164.0      468.0        7.20
# AE            United Arab Emirates        118.0    83600.0       10.33
# AF                     Afghanistan         60.0   652230.0       32.49
# AG             Antigua and Barbuda        223.0      443.0       15.33
# AL                         Albania        105.0    28748.0       11.78
# ...                            ...          ...        ...         ...
# EW                        Eswatini         67.0    17364.0         NaN
# VA                    Vatican City       2003.0        0.0         NaN
# RI             Republic of Ireland         72.0    70273.0       12.50
# NB                         Namibia          3.0   824292.0       28.64
# NM                 North Macedonia         83.0    25713.0         NaN
#
#               CO2_Emissions     CPI  Fertility_Rate           GDP  \
# Abbreviation
# AD                    469.0     NaN            1.27  3.154058e+09
# AE                 206324.0  114.52            1.41  4.211420e+11
# AF                   8672.0  149.90            4.47  1.910135e+10
# AG                    557.0  113.81            1.99  1.727759e+09
# AL                   4536.0  119.05            1.62  1.527808e+10
# ...                     ...     ...             ...           ...
# EW                      NaN     NaN             NaN  3.791304e+09
# VA                      NaN     NaN             NaN           NaN
# RI                  37711.0  106.58            1.75  3.886990e+11
# NB                   4228.0  157.97            3.40  1.236653e+10
# NM                      NaN     NaN             NaN  1.022078e+10
#
#               Infant mortality_per_1k  Life_Expectancy  \
# Abbreviation
# AD                                2.7              NaN
# AE                                6.5             77.8
# AF                               47.9             64.5
# AG                                5.0             76.9
# AL                                7.8             78.5
# ...                               ...              ...
# EW                                NaN              NaN
# VA                                NaN              NaN
# RI                                3.1             82.3
# NB                               29.0             63.4
# NM                                NaN              NaN
#
#               Maternal_Mortality_per_100k  Minimum_Wage Official Language  \
# Abbreviation
# AD                                    NaN          6.63           Catalan
# AE                                    3.0           NaN            Arabic
# AF                                  638.0          0.43            Pashto
# AG                                   42.0          3.04           English
# AL                                   15.0          1.12          Albanian
# ...                                   ...           ...               ...
# EW                                    NaN           NaN           English
# VA                                    NaN           NaN           Italian
# RI                                    5.0         10.79             Irish
# NB                                  195.0           NaN           English
# NM                                    NaN           NaN        Macedonian
#
#               oop_health_exp  Physicians_per_1k  Population  Unemployment_Rate
# Abbreviation
# AD                      0.36               3.33     77142.0                NaN
# AE                      0.18               2.53   9770529.0               0.02
# AF                      0.78               0.28  38041754.0               0.11
# AG                      0.24               2.76     97118.0                NaN
# AL                      0.57               1.20   2854191.0               0.12
# ...                      ...                ...         ...                ...
# EW                      0.11                NaN   1093238.0                NaN
# VA                       NaN                NaN       836.0                NaN
# RI                      0.15               3.31   5007069.0               0.05
# NB                      0.08               0.42   2494530.0               0.20
# NM                      0.36                NaN   1836713.0                NaN
#
# [194 rows x 17 columns]

# %%
#sort DataFrame by index
world_health_df = world_health_df.sort_index()

# %% [markdown]
# ###Question 3: What nation has the index value "DZ"

# %%
world_health_df.loc['DZ']
# Out:
# Country                               Algeria
# Pop_Density                              18.0
# Land_Area                           2381741.0
# Birth_Rate                              24.28
# CO2_Emissions                        150006.0
# CPI                                    151.36
# Fertility_Rate                           3.02
# GDP                            169988000000.0
# Infant mortality_per_1k                  20.1
# Life_Expectancy                          76.7
# Maternal_Mortality_per_100k             112.0
# Minimum_Wage                             0.95
# Official Language                      Arabic
# oop_health_exp                           0.28
# Physicians_per_1k                        1.72
# Population                         43053054.0
# Unemployment_Rate                        0.12
# Name: DZ, dtype: object

# %% [markdown]
# ##Update Notebook

# %%
# Delete Vatican City from DataFrame
world_health_df = world_health_df.drop('VA')

# %%
# check work
world_health_df.tail(10)
# Out:
#                                        Country  Pop_Density  Land_Area  \
# Abbreviation
# UZ                                  Uzbekistan         79.0   447400.0
# VC            Saint Vincent and the Grenadines        284.0      389.0
# VE                                   Venezuela         32.0   912050.0
# VN                                     Vietnam        314.0   331210.0
# VU                                     Vanuatu         25.0    12189.0
# WS                                       Samoa         70.0     2831.0
# YE                                       Yemen         56.0   527968.0
# ZA                                South Africa         49.0  1219090.0
# ZM                                      Zambia         25.0   752618.0
# ZW                                    Zimbabwe         38.0   390757.0
#
#               Birth_Rate  CO2_Emissions      CPI  Fertility_Rate  \
# Abbreviation
# UZ                 23.30        91811.0      NaN            2.42
# VC                 14.24          220.0   109.67            1.89
# VE                 17.88       164175.0  2740.27            2.27
# VN                 16.75       192668.0   163.52            2.05
# VU                 29.60          147.0   117.13            3.78
# WS                 24.38          246.0   117.56            3.88
# YE                 30.45        10609.0   157.58            3.79
# ZA                 20.51       476644.0   158.93            2.41
# ZM                 36.19         5141.0   212.31            4.63
# ZW                 30.68        10983.0   105.51            3.62
#
#                        GDP  Infant mortality_per_1k  Life_Expectancy  \
# Abbreviation
# UZ            5.792129e+10                     19.1             71.6
# VC            8.253852e+08                     14.8             72.4
# VE            4.823590e+11                     21.4             72.1
# VN            2.619210e+11                     16.5             75.3
# VU            9.170589e+08                     22.3             70.3
# WS            8.506550e+08                     13.6             73.2
# YE            2.691440e+10                     42.9             66.1
# ZA            3.514320e+11                     28.5             63.9
# ZM            2.306472e+10                     40.4             63.5
# ZW            2.144076e+10                     33.9             61.2
#
#               Maternal_Mortality_per_100k  Minimum_Wage Official Language  \
# Abbreviation
# UZ                                   29.0          0.24             Uzbek
# VC                                   68.0          1.16           English
# VE                                  125.0          0.01           Spanish
# VN                                   43.0          0.73        Vietnamese
# VU                                   72.0          1.56            French
# WS                                   43.0          0.78            Samoan
# YE                                  164.0           NaN            Arabic
# ZA                                  119.0           NaN         Afrikaans
# ZM                                  213.0          0.24           English
# ZW                                  458.0           NaN             Shona
#
#               oop_health_exp  Physicians_per_1k  Population  Unemployment_Rate
# Abbreviation
# UZ                      0.43               2.37  33580650.0               0.06
# VC                      0.21               0.66    100455.0               0.19
# VE                      0.46               1.92  28515829.0               0.09
# VN                      0.44               0.82  96462106.0               0.02
# VU                      0.09               0.17    299882.0               0.04
# WS                      0.12               0.34    202506.0               0.08
# YE                      0.81               0.31  29161922.0               0.13
# ZA                      0.08               0.91  58558270.0               0.28
# ZM                      0.28               1.19  17861030.0               0.11
# ZW                      0.26               0.21  14645468.0               0.05

# %% [markdown]
# ###Question 4: What is the official language of the nation on the 186th row?

# %%
# offocial language of nation on 186th row

world_health_df.iloc[185]
# Out:
# Country                             Venezuela
# Pop_Density                              32.0
# Land_Area                            912050.0
# Birth_Rate                              17.88
# CO2_Emissions                        164175.0
# CPI                                   2740.27
# Fertility_Rate                           2.27
# GDP                            482359000000.0
# Infant mortality_per_1k                  21.4
# Life_Expectancy                          72.1
# Maternal_Mortality_per_100k             125.0
# Minimum_Wage                             0.01
# Official Language                     Spanish
# oop_health_exp                           0.46
# Physicians_per_1k                        1.92
# Population                         28515829.0
# Unemployment_Rate                        0.09
# Name: VE, dtype: object

# %% [markdown]
# ##Sort dataframe by infant mortaility. highest to lowest

# %%
#sort by infant mortality, high to low
world_health_df = world_health_df.sort_values('Infant mortality_per_1k', ascending = False)

# %%
# Top 10 nations with the highest infant mortality. What continent?
world_health_df.head(10)
# Out:
#                                        Country  Pop_Density  Land_Area  \
# Abbreviation
# CF                    Central African Republic          8.0   622984.0
# SL                                Sierra Leone        111.0    71740.0
# SO                                     Somalia         25.0   637657.0
# NG                                     Nigeria        226.0   923768.0
# TD                                        Chad         13.0  1284000.0
# CD            Democratic Republic of the Congo         40.0  2344858.0
# LS                                     Lesotho         71.0    30355.0
# GN                                      Guinea         53.0   245857.0
# SS                                 South Sudan         18.0   644329.0
# GQ                           Equatorial Guinea         50.0    28051.0
#
#               Birth_Rate  CO2_Emissions      CPI  Fertility_Rate  \
# Abbreviation
# CF                 35.35          297.0   186.86            4.72
# SL                 33.41         1093.0   234.16            4.26
# SO                 41.75          645.0      NaN            6.07
# NG                 37.91       120369.0   267.51            5.39
# TD                 42.17         1016.0   117.70            5.75
# CD                 41.18         2021.0   133.85            5.92
# LS                 26.81         2512.0   155.86            3.14
# GN                 36.36         2996.0   262.95            4.70
# SS                 35.01         1727.0  4583.71            4.70
# GQ                 33.24         5655.0   124.35            4.51
#
#                        GDP  Infant mortality_per_1k  Life_Expectancy  \
# Abbreviation
# CF            2.220307e+09                     84.5             52.8
# SL            3.941474e+09                     78.5             54.3
# SO            4.720727e+09                     76.6             57.1
# NG            4.481200e+11                     75.7             54.3
# TD            1.131495e+10                     71.4             54.0
# CD            4.731962e+10                     68.2             60.4
# LS            2.460072e+09                     65.7             53.7
# GN            1.359028e+10                     64.9             61.2
# SS            1.199780e+10                     63.7             57.6
# GQ            1.102677e+10                     62.6             58.4
#
#               Maternal_Mortality_per_100k  Minimum_Wage Official Language  \
# Abbreviation
# CF                                  829.0          0.37            French
# SL                                 1120.0          0.57           English
# SO                                  829.0           NaN            Arabic
# NG                                  917.0          0.54           English
# TD                                 1140.0          0.60            French
# CD                                  473.0          0.18            French
# LS                                  544.0          0.41           English
# GN                                  576.0           NaN            French
# SS                                 1150.0           NaN           English
# GQ                                  301.0          1.05           Spanish
#
#               oop_health_exp  Physicians_per_1k   Population  \
# Abbreviation
# CF                      0.40               0.06    4745185.0
# SL                      0.38               0.03    7813215.0
# SO                       NaN               0.02   15442905.0
# NG                      0.72               0.38  200963599.0
# TD                      0.56               0.04   15946876.0
# CD                      0.37               0.07   86790567.0
# LS                      0.17               0.07    2125268.0
# GN                      0.55               0.08   12771246.0
# SS                      0.61                NaN   11062113.0
# GQ                      0.72               0.40    1355986.0
#
#               Unemployment_Rate
# Abbreviation
# CF                         0.04
# SL                         0.04
# SO                         0.11
# NG                         0.08
# TD                         0.02
# CD                         0.04
# LS                         0.23
# GN                         0.04
# SS                         0.12
# GQ                         0.06

# %% [markdown]
# ##Create new dataframe for countries whose official language is Spanish

# %%
# How many rows are in the new dataframe?

# create filter
spanish_language_filter = world_health_df['Official Language'] == 'Spanish'

# apply filter
world_health_df[spanish_language_filter]

#count
world_health_df[spanish_language_filter].shape
# Out:
# (19, 17)

# %%
# mean infant mortality per 1k infants in countires whose official language is Spanish

world_health_df[spanish_language_filter]['Infant mortality_per_1k'].mean()
# Out:
# np.float64(15.557894736842103)

# %%
# what is the median maternal mortality in counties whose official langiage is Spanish

world_health_df[spanish_language_filter]['Maternal_Mortality_per_100k'].median()
# Out:
# 65.0

# %%
# create GDP per capita field

world_health_df['GDP_per_capita'] = world_health_df['GDP'] / world_health_df['Population']

# %%
# check work
world_health_df.head()
# Out:
#                                Country  Pop_Density  Land_Area  Birth_Rate  \
# Abbreviation
# CF            Central African Republic          8.0   622984.0       35.35
# SL                        Sierra Leone        111.0    71740.0       33.41
# SO                             Somalia         25.0   637657.0       41.75
# NG                             Nigeria        226.0   923768.0       37.91
# TD                                Chad         13.0  1284000.0       42.17
#
#               CO2_Emissions     CPI  Fertility_Rate           GDP  \
# Abbreviation
# CF                    297.0  186.86            4.72  2.220307e+09
# SL                   1093.0  234.16            4.26  3.941474e+09
# SO                    645.0     NaN            6.07  4.720727e+09
# NG                 120369.0  267.51            5.39  4.481200e+11
# TD                   1016.0  117.70            5.75  1.131495e+10
#
#               Infant mortality_per_1k  Life_Expectancy  \
# Abbreviation
# CF                               84.5             52.8
# SL                               78.5             54.3
# SO                               76.6             57.1
# NG                               75.7             54.3
# TD                               71.4             54.0
#
#               Maternal_Mortality_per_100k  Minimum_Wage Official Language  \
# Abbreviation
# CF                                  829.0          0.37            French
# SL                                 1120.0          0.57           English
# SO                                  829.0           NaN            Arabic
# NG                                  917.0          0.54           English
# TD                                 1140.0          0.60            French
#
#               oop_health_exp  Physicians_per_1k   Population  \
# Abbreviation
# CF                      0.40               0.06    4745185.0
# SL                      0.38               0.03    7813215.0
# SO                       NaN               0.02   15442905.0
# NG                      0.72               0.38  200963599.0
# TD                      0.56               0.04   15946876.0
#
#               Unemployment_Rate  GDP_per_capita
# Abbreviation
# CF                         0.04      467.907441
# SL                         0.04      504.462543
# SO                         0.11      305.689071
# NG                         0.08     2229.856562
# TD                         0.02      709.540310

# %%
# Sort by GDP per capita, high to low
world_health_df = world_health_df.sort_values('GDP_per_capita', ascending = False)

# %%
# check work
world_health_df.iloc[3]
# Out:
# Country                           Switzerland
# Pop_Density                             219.0
# Land_Area                             41277.0
# Birth_Rate                               10.0
# CO2_Emissions                         34477.0
# CPI                                     99.55
# Fertility_Rate                           1.52
# GDP                            703082000000.0
# Infant mortality_per_1k                   3.7
# Life_Expectancy                          83.6
# Maternal_Mortality_per_100k               5.0
# Minimum_Wage                              NaN
# Official Language                      German
# oop_health_exp                           0.28
# Physicians_per_1k                         4.3
# Population                          8574832.0
# Unemployment_Rate                        0.05
# GDP_per_capita                   81993.676378
# Name: CH, dtype: object

# %%
# Average maternal mortality rate per 100k for all nations?

world_health_df['Maternal_Mortality_per_100k'].mean()
# Out:
# np.float64(160.39226519337018)

# %%
# WHat percentage of health care is paid out of pocket by country with the lowest infant mortality?
world_health_df.sort_values('Infant mortality_per_1k', ascending = True).head()
# Out:
#                  Country  Pop_Density  Land_Area  Birth_Rate  CO2_Emissions  \
# Abbreviation
# FI               Finland         18.0   338145.0         8.6        45871.0
# IS               Iceland          3.0   103000.0        12.0         2065.0
# SM            San Marino        566.0       61.0         6.8            NaN
# SI              Slovenia        103.0    20273.0         9.4        12633.0
# JP                 Japan        347.0   377944.0         7.4      1135886.0
#
#                  CPI  Fertility_Rate           GDP  Infant mortality_per_1k  \
# Abbreviation
# FI            112.33            1.41  2.687610e+11                      1.4
# IS            129.00            1.71  2.418804e+10                      1.5
# SM            110.63            1.26  1.637931e+09                      1.7
# SI            111.05            1.60  5.374216e+10                      1.7
# JP            105.48            1.42  5.081770e+12                      1.8
#
#               Life_Expectancy  Maternal_Mortality_per_100k  Minimum_Wage  \
# Abbreviation
# FI                       81.7                          3.0           NaN
# IS                       82.7                          4.0           NaN
# SM                       85.4                          NaN           NaN
# SI                       81.0                          7.0          5.25
# JP                       84.2                          5.0          6.77
#
#              Official Language  oop_health_exp  Physicians_per_1k  \
# Abbreviation
# FI                     Swedish            0.20               3.81
# IS                   Icelandic            0.17               4.08
# SM                     Italian            0.18               6.11
# SI            Slovene language            0.13               3.09
# JP                         NaN            0.13               2.41
#
#                Population  Unemployment_Rate  GDP_per_capita
# Abbreviation
# FI              5520314.0               0.07    48685.817510
# IS               361313.0               0.03    66944.825509
# SM                33860.0                NaN    48373.627702
# SI              2087946.0               0.04    25739.247814
# JP            126226568.0               0.02    40259.115656

# %%
# WHat percentage of health care is paid out of pocket by country with the highest infant mortality?
world_health_df.sort_values('Infant mortality_per_1k', ascending = False).head()
# Out:
#                                Country  Pop_Density  Land_Area  Birth_Rate  \
# Abbreviation
# CF            Central African Republic          8.0   622984.0       35.35
# SL                        Sierra Leone        111.0    71740.0       33.41
# SO                             Somalia         25.0   637657.0       41.75
# NG                             Nigeria        226.0   923768.0       37.91
# TD                                Chad         13.0  1284000.0       42.17
#
#               CO2_Emissions     CPI  Fertility_Rate           GDP  \
# Abbreviation
# CF                    297.0  186.86            4.72  2.220307e+09
# SL                   1093.0  234.16            4.26  3.941474e+09
# SO                    645.0     NaN            6.07  4.720727e+09
# NG                 120369.0  267.51            5.39  4.481200e+11
# TD                   1016.0  117.70            5.75  1.131495e+10
#
#               Infant mortality_per_1k  Life_Expectancy  \
# Abbreviation
# CF                               84.5             52.8
# SL                               78.5             54.3
# SO                               76.6             57.1
# NG                               75.7             54.3
# TD                               71.4             54.0
#
#               Maternal_Mortality_per_100k  Minimum_Wage Official Language  \
# Abbreviation
# CF                                  829.0          0.37            French
# SL                                 1120.0          0.57           English
# SO                                  829.0           NaN            Arabic
# NG                                  917.0          0.54           English
# TD                                 1140.0          0.60            French
#
#               oop_health_exp  Physicians_per_1k   Population  \
# Abbreviation
# CF                      0.40               0.06    4745185.0
# SL                      0.38               0.03    7813215.0
# SO                       NaN               0.02   15442905.0
# NG                      0.72               0.38  200963599.0
# TD                      0.56               0.04   15946876.0
#
#               Unemployment_Rate  GDP_per_capita
# Abbreviation
# CF                         0.04      467.907441
# SL                         0.04      504.462543
# SO                         0.11      305.689071
# NG                         0.08     2229.856562
# TD                         0.02      709.540310
